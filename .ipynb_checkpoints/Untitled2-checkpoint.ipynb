# %%
import pandas as pd
import requests
import time

# %%
unemp_data=pd.read_csv("unemp_rate.csv")
unemp_data
unemp_data.set_index('Date',inplace=True)
unemp_data
# Out:
#             Unemp_Hispanic  Unemp_Asian  Unemp_Black  Unemp_White  \
# Date
# 2021-03-01             7.9          5.9          9.6          5.4
# 2021-02-01             8.5          5.1          9.9          5.6
# 2021-01-01             8.6          6.8          9.2          5.7
# 2020-12-01             9.3          5.8          9.9          6.0
# 2020-11-01             8.4          6.7         10.3          5.9
# ...                    ...          ...          ...          ...
# 1948-05-01             NaN          NaN          NaN          NaN
# 1948-04-01             NaN          NaN          NaN          NaN
# 1948-03-01             NaN          NaN          NaN          NaN
# 1948-02-01             NaN          NaN          NaN          NaN
# 1948-01-01             NaN          NaN          NaN          NaN
#
#             Unemp_Civilian  Unemp_Men  Unemp_Women  Unemp_White_Men  20-24  \
# Date
# 2021-03-01             6.0        6.2          5.9            3.348   10.3
# ...
